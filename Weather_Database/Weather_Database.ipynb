# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
#Adding the dependencies
import numpy as np
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
import requests
import sys
import os
sys.path.insert(1, os.path.join("..","."))
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(-90,90,size = 2000)
lngs = np.random.uniform(-180,180,size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 772

# %%
#Performing API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0d39686a781a93b95e99fac1569f508a

# %%
#Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval   ")
print("---------------------------")
# Create counters.
record_count = 1
set_count = 1
for i,city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if(i%50==0 and i>=50):
        set_count+=1
        record_count = 1
        time.sleep(10)
        
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record{record_count} of Set{set_count} | {city}")
    # Add 1 to the record count.
    record_count+=1
# Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
#         city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({
            "City":city.title(),
            "Lat":city_lat,
            "Lng": city_lng,                 
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
#             "Date": city_date 
            "Current Description":city_description
        })
    except:
        print("City not found.Skipping....")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record1 of Set1 | albany
# Processing Record2 of Set1 | yuancheng
# Processing Record3 of Set1 | illoqqortoormiut
# City not found.Skipping....
# Processing Record4 of Set1 | high level
# Processing Record5 of Set1 | rikitea
# Processing Record6 of Set1 | mataura
# Processing Record7 of Set1 | jamestown
# Processing Record8 of Set1 | petropavlovsk-kamchatskiy
# Processing Record9 of Set1 | punta arenas
# Processing Record10 of Set1 | kapit
# Processing Record11 of Set1 | georgetown
# Processing Record12 of Set1 | dandong
# Processing Record13 of Set1 | zheleznodorozhnyy
# Processing Record14 of Set1 | thompson
# Processing Record15 of Set1 | ushuaia
# Processing Record16 of Set1 | norman wells
# Processing Record17 of Set1 | tuatapere
# Processing Record18 of Set1 | osi
# Processing Record19 of Set1 | tasiilaq
# Processing Record20 of Set1 | zabaykalsk
# Processing Record21 of Set1 | xai-xai
# Processing Record22 of Set1 | nuuk
# Processing Record23 of Set1 | rungata
# City not found.Skipping....
# Processing Record24 of Set1 | ankang
# Processing Record25 of Set1 | qaanaaq
# Processing Record26 of Set1 | brownwood
# Processing Record27 of Set1 | ponta do sol
# Processing Record28 of Set1 | dombarovskiy
# Processing Record29 of Set1 | kaz
# Processing Record30 of Set1 | dahuk
# Processing Record31 of Set1 | jensen beach
# Processing Record32 of Set1 | romita
# Processing Record33 of Set1 | cape town
# Processing Record34 of Set1 | tsihombe
# City not found.Skipping....
# Processing Record35 of Set1 | codrington
# Processing Record36 of Set1 | maniitsoq
# Processing Record37 of Set1 | barcelona
# Processing Record38 of Set1 | provideniya
# Processing Record39 of Set1 | new norfolk
# Processing Record40 of Set1 | bluff
# Processing Record41 of Set1 | manaure
# Processing Record42 of Set1 | hilo
# Processing Record43 of Set1 | port alfred
# Processing Record44 of Set1 | leh
# Processing Record45 of Set1 | tuktoyaktuk
# Processing Record46 of Set1 | hobart
# Processing Record47 of Set1 | constitucion
# Processing Record48 of Set1 | butaritari
# Processing Record49 of Set1 | bredasdorp
# Processing Record50 of Set1 | yellowknife
# Processing Record1 of Set2 | avarua
# Processing Record2 of Set2 | lavrentiya
# Processing Record3 of Set2 | taolanaro
# City not found.Skipping....
# Processing Record4 of Set2 | hithadhoo
# Processing Record5 of Set2 | elizabeth city
# Processing Record6 of Set2 | ucluelet
# Processing Record7 of Set2 | saint george
# Processing Record8 of Set2 | busselton
# Processing Record9 of Set2 | barentsburg
# City not found.Skipping....
# Processing Record10 of Set2 | taoudenni
# Processing Record11 of Set2 | minas
# Processing Record12 of Set2 | boueni
# Processing Record13 of Set2 | sault sainte marie
# Processing Record14 of Set2 | port hueneme
# Processing Record15 of Set2 | cockburn town
# Processing Record16 of Set2 | ancud
# Processing Record17 of Set2 | atuona
# Processing Record18 of Set2 | nelson bay
# Processing Record19 of Set2 | adrar
# Processing Record20 of Set2 | upernavik
# Processing Record21 of Set2 | kyabe
# Processing Record22 of Set2 | sentyabrskiy
# City not found.Skipping....
# Processing Record23 of Set2 | grand-santi
# Processing Record24 of Set2 | vaini
# Processing Record25 of Set2 | tumannyy
# City not found.Skipping....
# Processing Record26 of Set2 | ndouci
# City not found.Skipping....
# Processing Record27 of Set2 | big rapids
# Processing Record28 of Set2 | hermanus
# Processing Record29 of Set2 | muros
# Processing Record30 of Set2 | fortuna
# Processing Record31 of Set2 | polyanka
# Processing Record32 of Set2 | kodiak
# Processing Record33 of Set2 | belushya guba
# City not found.Skipping....
# Processing Record34 of Set2 | ust-bolsheretsk
# City not found.Skipping....
# Processing Record35 of Set2 | jambi
# Processing Record36 of Set2 | carnarvon
# Processing Record37 of Set2 | nouadhibou
# Processing Record38 of Set2 | alofi
# Processing Record39 of Set2 | santa cruz
# Processing Record40 of Set2 | magistralnyy
# Processing Record41 of Set2 | prince rupert
# Processing Record42 of Set2 | samusu
# City not found.Skipping....
# Processing Record43 of Set2 | lagoa
# Processing Record44 of Set2 | saleaula
# City not found.Skipping....
# Processing Record45 of Set2 | port lincoln
# Processing Record46 of Set2 | kapaa
# Processing Record47 of Set2 | victoria
# Processing Record48 of Set2 | moultonborough
# Processing Record49 of Set2 | mar del plata
# Processing Record50 of Set2 | bambous virieux
# Processing Record1 of Set3 | buala
# Processing Record2 of Set3 | yumen
# Processing Record3 of Set3 | bethel
# Processing Record4 of Set3 | tiksi
# Processing Record5 of Set3 | saint-jean-port-joli
# Processing Record6 of Set3 | nha trang
# Processing Record7 of Set3 | kirakira
# Processing Record8 of Set3 | chokurdakh
# Processing Record9 of Set3 | camacha
# Processing Record10 of Set3 | lebu
# Processing Record11 of Set3 | pevek
# Processing Record12 of Set3 | carutapera
# Processing Record13 of Set3 | klaksvik
# Processing Record14 of Set3 | nikel
# Processing Record15 of Set3 | puerto ayora
# Processing Record16 of Set3 | margate
# Processing Record17 of Set3 | dingle
# Processing Record18 of Set3 | enid
# Processing Record19 of Set3 | itarema
# Processing Record20 of Set3 | xichang
# Processing Record21 of Set3 | baykit
# Processing Record22 of Set3 | shimoda
# Processing Record23 of Set3 | morshyn
# Processing Record24 of Set3 | narsaq
# Processing Record25 of Set3 | guerrero negro
# Processing Record26 of Set3 | bac lieu
# Processing Record27 of Set3 | yarada
# Processing Record28 of Set3 | teguldet
# Processing Record29 of Set3 | barrow
# Processing Record30 of Set3 | savannakhet
# Processing Record31 of Set3 | pisco
# Processing Record32 of Set3 | east london
# Processing Record33 of Set3 | belmonte
# Processing Record34 of Set3 | amderma
# City not found.Skipping....
# Processing Record35 of Set3 | mount gambier
# Processing Record36 of Set3 | odienne
# Processing Record37 of Set3 | castro
# Processing Record38 of Set3 | gorontalo
# Processing Record39 of Set3 | saldanha
# Processing Record40 of Set3 | san ramon
# Processing Record41 of Set3 | sur
# Processing Record42 of Set3 | berdigestyakh
# Processing Record43 of Set3 | halalo
# City not found.Skipping....
# Processing Record44 of Set3 | talara
# Processing Record45 of Set3 | vao
# Processing Record46 of Set3 | mahebourg
# Processing Record47 of Set3 | tamandare
# Processing Record48 of Set3 | zhuhai
# Processing Record49 of Set3 | mys shmidta
# City not found.Skipping....
# Processing Record50 of Set3 | puri
# Processing Record1 of Set4 | leningradskiy
# Processing Record2 of Set4 | camana
# Processing Record3 of Set4 | san pedro
# Processing Record4 of Set4 | chulym
# Processing Record5 of Set4 | soure
# Processing Record6 of Set4 | ayan
# Processing Record7 of Set4 | cidreira
# Processing Record8 of Set4 | youghal
# Processing Record9 of Set4 | faanui
# Processing Record10 of Set4 | flinders
# Processing Record11 of Set4 | patti
# Processing Record12 of Set4 | caconda
# Processing Record13 of Set4 | aswan
# Processing Record14 of Set4 | cordoba
# Processing Record15 of Set4 | broome
# Processing Record16 of Set4 | mitsamiouli
# Processing Record17 of Set4 | mariestad
# Processing Record18 of Set4 | saint-philippe
# Processing Record19 of Set4 | saint anthony
# Processing Record20 of Set4 | yuncheng
# Processing Record21 of Set4 | caraguatay
# Processing Record22 of Set4 | sept-iles
# Processing Record23 of Set4 | plouzane
# Processing Record24 of Set4 | torbay
# Processing Record25 of Set4 | ribeira grande
# Processing Record26 of Set4 | port elizabeth
# Processing Record27 of Set4 | nybro
# Processing Record28 of Set4 | bengkulu
# Processing Record29 of Set4 | kamenskoye
# City not found.Skipping....
# Processing Record30 of Set4 | ilulissat
# Processing Record31 of Set4 | anadyr
# Processing Record32 of Set4 | puerto narino
# Processing Record33 of Set4 | northam
# Processing Record34 of Set4 | puerto del rosario
# Processing Record35 of Set4 | tete
# Processing Record36 of Set4 | goundam
# Processing Record37 of Set4 | airai
# Processing Record38 of Set4 | deputatskiy
# Processing Record39 of Set4 | mangai
# Processing Record40 of Set4 | touros
# Processing Record41 of Set4 | garowe
# Processing Record42 of Set4 | lumut
# Processing Record43 of Set4 | tupik
# Processing Record44 of Set4 | kamenka
# Processing Record45 of Set4 | muisne
# Processing Record46 of Set4 | tura
# Processing Record47 of Set4 | khatanga
# Processing Record48 of Set4 | padang
# Processing Record49 of Set4 | santa maria
# Processing Record50 of Set4 | coos bay
# Processing Record1 of Set5 | cabo san lucas
# Processing Record2 of Set5 | ngukurr
# City not found.Skipping....
# Processing Record3 of Set5 | kavaratti
# Processing Record4 of Set5 | teo
# Processing Record5 of Set5 | te anau
# Processing Record6 of Set5 | tessalit
# Processing Record7 of Set5 | moyamba
# Processing Record8 of Set5 | soldotna
# Processing Record9 of Set5 | cherskiy
# Processing Record10 of Set5 | port hawkesbury
# Processing Record11 of Set5 | shingu
# Processing Record12 of Set5 | caala
# Processing Record13 of Set5 | chirongui
# Processing Record14 of Set5 | turukhansk
# Processing Record15 of Set5 | roma
# Processing Record16 of Set5 | carinhanha
# Processing Record17 of Set5 | green river
# Processing Record18 of Set5 | alta floresta
# Processing Record19 of Set5 | shetpe
# Processing Record20 of Set5 | areia branca
# Processing Record21 of Set5 | severo-kurilsk
# Processing Record22 of Set5 | biak
# Processing Record23 of Set5 | singaraja
# Processing Record24 of Set5 | scarborough
# Processing Record25 of Set5 | tazovskiy
# Processing Record26 of Set5 | riyadh
# Processing Record27 of Set5 | portland
# Processing Record28 of Set5 | kochi
# Processing Record29 of Set5 | maceio
# Processing Record30 of Set5 | longyearbyen
# Processing Record31 of Set5 | naron
# Processing Record32 of Set5 | ponta delgada
# Processing Record33 of Set5 | fonte boa
# Processing Record34 of Set5 | choctaw
# Processing Record35 of Set5 | mehamn
# Processing Record36 of Set5 | magadan
# Processing Record37 of Set5 | adre
# Processing Record38 of Set5 | fairbanks
# Processing Record39 of Set5 | salinas
# Processing Record40 of Set5 | maykor
# Processing Record41 of Set5 | chapais
# Processing Record42 of Set5 | yatou
# Processing Record43 of Set5 | khudumelapye
# Processing Record44 of Set5 | kaitong
# Processing Record45 of Set5 | hambantota
# Processing Record46 of Set5 | urdzhar
# City not found.Skipping....
# Processing Record47 of Set5 | markala
# Processing Record48 of Set5 | gbongan
# Processing Record49 of Set5 | tadine
# Processing Record50 of Set5 | malm
# Processing Record1 of Set6 | jiazi
# Processing Record2 of Set6 | odweyne
# Processing Record3 of Set6 | the valley
# Processing Record4 of Set6 | san ignacio
# Processing Record5 of Set6 | poso
# Processing Record6 of Set6 | zhigansk
# Processing Record7 of Set6 | luderitz
# Processing Record8 of Set6 | soe
# Processing Record9 of Set6 | kawana waters
# City not found.Skipping....
# Processing Record10 of Set6 | richards bay
# Processing Record11 of Set6 | erdenet
# Processing Record12 of Set6 | yenagoa
# Processing Record13 of Set6 | flin flon
# Processing Record14 of Set6 | buraydah
# Processing Record15 of Set6 | bereda
# Processing Record16 of Set6 | taua
# Processing Record17 of Set6 | rovenki
# Processing Record18 of Set6 | townsville
# Processing Record19 of Set6 | remanso
# Processing Record20 of Set6 | kysyl-syr
# Processing Record21 of Set6 | casablanca
# Processing Record22 of Set6 | portsmouth
# Processing Record23 of Set6 | kangaatsiaq
# Processing Record24 of Set6 | dronten
# Processing Record25 of Set6 | verkhoyansk
# Processing Record26 of Set6 | meleuz
# Processing Record27 of Set6 | izumo
# Processing Record28 of Set6 | vaitupu
# City not found.Skipping....
# Processing Record29 of Set6 | boca do acre
# Processing Record30 of Set6 | kojetin
# Processing Record31 of Set6 | isangel
# Processing Record32 of Set6 | biloela
# Processing Record33 of Set6 | sao filipe
# Processing Record34 of Set6 | jutai
# Processing Record35 of Set6 | grand-lahou
# Processing Record36 of Set6 | aykhal
# Processing Record37 of Set6 | guangzhou
# Processing Record38 of Set6 | nagua
# Processing Record39 of Set6 | tahe
# Processing Record40 of Set6 | grand river south east
# City not found.Skipping....
# Processing Record41 of Set6 | hunza
# City not found.Skipping....
# Processing Record42 of Set6 | ravenna
# Processing Record43 of Set6 | sobolevo
# Processing Record44 of Set6 | katsuura
# Processing Record45 of Set6 | chuy
# Processing Record46 of Set6 | kamsack
# Processing Record47 of Set6 | nikolskoye
# Processing Record48 of Set6 | waverly
# Processing Record49 of Set6 | nioro
# Processing Record50 of Set6 | huarmey
# Processing Record1 of Set7 | debre birhan
# Processing Record2 of Set7 | saskylakh
# Processing Record3 of Set7 | falealupo
# City not found.Skipping....
# Processing Record4 of Set7 | ambodifototra
# City not found.Skipping....
# Processing Record5 of Set7 | khairagarh
# Processing Record6 of Set7 | rincon
# Processing Record7 of Set7 | fez
# Processing Record8 of Set7 | el tigre
# Processing Record9 of Set7 | nome
# Processing Record10 of Set7 | gat
# Processing Record11 of Set7 | srednekolymsk
# Processing Record12 of Set7 | sinjai
# Processing Record13 of Set7 | north myrtle beach
# Processing Record14 of Set7 | hami
# Processing Record15 of Set7 | itoman
# Processing Record16 of Set7 | zemio
# Processing Record17 of Set7 | rocha
# Processing Record18 of Set7 | labutta
# City not found.Skipping....
# Processing Record19 of Set7 | tabarqah
# City not found.Skipping....
# Processing Record20 of Set7 | catuday
# Processing Record21 of Set7 | ermelo
# Processing Record22 of Set7 | clarksdale
# Processing Record23 of Set7 | sola
# Processing Record24 of Set7 | cambridge
# Processing Record25 of Set7 | limoeiro do ajuru
# Processing Record26 of Set7 | umzimvubu
# City not found.Skipping....
# Processing Record27 of Set7 | ordu
# Processing Record28 of Set7 | mandalgovi
# Processing Record29 of Set7 | faya
# Processing Record30 of Set7 | manokwari
# Processing Record31 of Set7 | talnakh
# Processing Record32 of Set7 | tilichiki
# Processing Record33 of Set7 | biltine
# Processing Record34 of Set7 | conde
# Processing Record35 of Set7 | hobyo
# Processing Record36 of Set7 | namibe
# Processing Record37 of Set7 | dudinka
# Processing Record38 of Set7 | umm lajj
# Processing Record39 of Set7 | mugur-aksy
# Processing Record40 of Set7 | cayenne
# Processing Record41 of Set7 | lorengau
# Processing Record42 of Set7 | mandawar
# Processing Record43 of Set7 | vestmannaeyjar
# Processing Record44 of Set7 | mount pleasant
# Processing Record45 of Set7 | bima
# Processing Record46 of Set7 | turayf
# Processing Record47 of Set7 | esperance
# Processing Record48 of Set7 | tarudant
# City not found.Skipping....
# Processing Record49 of Set7 | santa maria da boa vista
# Processing Record50 of Set7 | la ronge
# Processing Record1 of Set8 | arlit
# Processing Record2 of Set8 | iqaluit
# Processing Record3 of Set8 | igarka
# Processing Record4 of Set8 | kununurra
# Processing Record5 of Set8 | rawson
# Processing Record6 of Set8 | kismayo
# Processing Record7 of Set8 | kavieng
# Processing Record8 of Set8 | podporozhye
# Processing Record9 of Set8 | marquard
# Processing Record10 of Set8 | verkhnyaya inta
# Processing Record11 of Set8 | buy
# Processing Record12 of Set8 | chia
# Processing Record13 of Set8 | college place
# Processing Record14 of Set8 | hasaki
# Processing Record15 of Set8 | lingao
# Processing Record16 of Set8 | moche
# Processing Record17 of Set8 | ipixuna
# Processing Record18 of Set8 | bouar
# Processing Record19 of Set8 | hai duong
# Processing Record20 of Set8 | laguna
# Processing Record21 of Set8 | oshnaviyeh
# Processing Record22 of Set8 | lompoc
# Processing Record23 of Set8 | alexandria
# Processing Record24 of Set8 | goma
# Processing Record25 of Set8 | vila
# Processing Record26 of Set8 | dikson
# Processing Record27 of Set8 | san cristobal
# Processing Record28 of Set8 | bandarbeyla
# Processing Record29 of Set8 | kaitangata
# Processing Record30 of Set8 | aklavik
# Processing Record31 of Set8 | ust-tsilma
# Processing Record32 of Set8 | ambunti
# Processing Record33 of Set8 | ukiah
# Processing Record34 of Set8 | nancha
# Processing Record35 of Set8 | honiara
# Processing Record36 of Set8 | tateyama
# Processing Record37 of Set8 | henties bay
# Processing Record38 of Set8 | pangnirtung
# Processing Record39 of Set8 | waipawa
# Processing Record40 of Set8 | jumla
# Processing Record41 of Set8 | hualmay
# Processing Record42 of Set8 | ridgecrest
# Processing Record43 of Set8 | arraial do cabo
# Processing Record44 of Set8 | paamiut
# Processing Record45 of Set8 | sembe
# Processing Record46 of Set8 | greensburg
# Processing Record47 of Set8 | thinadhoo
# Processing Record48 of Set8 | olafsvik
# Processing Record49 of Set8 | aldan
# Processing Record50 of Set8 | katangli
# Processing Record1 of Set9 | kutum
# Processing Record2 of Set9 | jalu
# Processing Record3 of Set9 | bodden town
# Processing Record4 of Set9 | edinburg
# Processing Record5 of Set9 | dillon
# Processing Record6 of Set9 | hamilton
# Processing Record7 of Set9 | amahai
# Processing Record8 of Set9 | ust-ilimsk
# Processing Record9 of Set9 | esmeraldas
# Processing Record10 of Set9 | husavik
# Processing Record11 of Set9 | pitimbu
# Processing Record12 of Set9 | fountain hills
# Processing Record13 of Set9 | kantemirovka
# Processing Record14 of Set9 | wuda
# Processing Record15 of Set9 | korsakovo
# Processing Record16 of Set9 | nago
# Processing Record17 of Set9 | kahului
# Processing Record18 of Set9 | malakal
# Processing Record19 of Set9 | araouane
# Processing Record20 of Set9 | bahia de caraquez
# Processing Record21 of Set9 | prince george
# Processing Record22 of Set9 | los llanos de aridane
# Processing Record23 of Set9 | aksu
# Processing Record24 of Set9 | college
# Processing Record25 of Set9 | palabuhanratu
# City not found.Skipping....
# Processing Record26 of Set9 | orcopampa
# Processing Record27 of Set9 | sao lourenco
# Processing Record28 of Set9 | seymchan
# Processing Record29 of Set9 | ibadan
# Processing Record30 of Set9 | kalabo
# Processing Record31 of Set9 | angoram
# Processing Record32 of Set9 | xinyu
# Processing Record33 of Set9 | tual
# Processing Record34 of Set9 | zeya
# Processing Record35 of Set9 | domna
# Processing Record36 of Set9 | saint-andre-avellin
# Processing Record37 of Set9 | sao joao da barra
# Processing Record38 of Set9 | merrill
# Processing Record39 of Set9 | zonguldak
# Processing Record40 of Set9 | harper
# Processing Record41 of Set9 | chiredzi
# Processing Record42 of Set9 | mackenzie
# Processing Record43 of Set9 | shahrud
# Processing Record44 of Set9 | vaitape
# Processing Record45 of Set9 | mozelos
# Processing Record46 of Set9 | tlahualilo
# City not found.Skipping....
# Processing Record47 of Set9 | skagastrond
# City not found.Skipping....
# Processing Record48 of Set9 | yershichi
# Processing Record49 of Set9 | boende
# Processing Record50 of Set9 | nhulunbuy
# Processing Record1 of Set10 | lethem
# Processing Record2 of Set10 | durban
# Processing Record3 of Set10 | nurota
# Processing Record4 of Set10 | vila franca do campo
# Processing Record5 of Set10 | den helder
# Processing Record6 of Set10 | vangaindrano
# Processing Record7 of Set10 | sohag
# Processing Record8 of Set10 | coulihaut
# City not found.Skipping....
# Processing Record9 of Set10 | duminichi
# Processing Record10 of Set10 | ozernovskiy
# Processing Record11 of Set10 | san quintin
# Processing Record12 of Set10 | jubayl
# City not found.Skipping....
# Processing Record13 of Set10 | beira
# Processing Record14 of Set10 | bartica
# Processing Record15 of Set10 | gao
# Processing Record16 of Set10 | darhan
# Processing Record17 of Set10 | zyryanovsk
# Processing Record18 of Set10 | lalibela
# Processing Record19 of Set10 | duki
# Processing Record20 of Set10 | yataity
# Processing Record21 of Set10 | vostok
# Processing Record22 of Set10 | guanica
# Processing Record23 of Set10 | sines
# Processing Record24 of Set10 | peace river
# Processing Record25 of Set10 | katherine
# Processing Record26 of Set10 | bairiki
# Processing Record27 of Set10 | clyde river
# Processing Record28 of Set10 | luanda
# Processing Record29 of Set10 | otradnoye
# Processing Record30 of Set10 | russkaya polyana
# Processing Record31 of Set10 | ahipara
# Processing Record32 of Set10 | muzhi
# Processing Record33 of Set10 | san rafael
# Processing Record34 of Set10 | vilyuysk
# Processing Record35 of Set10 | beringovskiy
# Processing Record36 of Set10 | port hardy
# Processing Record37 of Set10 | gualeguay
# Processing Record38 of Set10 | gejiu
# Processing Record39 of Set10 | litoral del san juan
# City not found.Skipping....
# Processing Record40 of Set10 | concarneau
# Processing Record41 of Set10 | saint-raphael
# Processing Record42 of Set10 | qui nhon
# Processing Record43 of Set10 | okhotsk
# Processing Record44 of Set10 | psedakh
# Processing Record45 of Set10 | krasnyy chikoy
# Processing Record46 of Set10 | bisira
# Processing Record47 of Set10 | khonuu
# City not found.Skipping....
# Processing Record48 of Set10 | gambo
# Processing Record49 of Set10 | pueblo nuevo
# Processing Record50 of Set10 | svetlyy
# Processing Record1 of Set11 | asau
# Processing Record2 of Set11 | port blair
# Processing Record3 of Set11 | mae sot
# Processing Record4 of Set11 | dauphin
# Processing Record5 of Set11 | lima
# Processing Record6 of Set11 | odessa
# Processing Record7 of Set11 | puerto leguizamo
# Processing Record8 of Set11 | saint-joseph
# Processing Record9 of Set11 | vardo
# Processing Record10 of Set11 | jacksonville
# Processing Record11 of Set11 | warqla
# City not found.Skipping....
# Processing Record12 of Set11 | foligno
# Processing Record13 of Set11 | careiro da varzea
# Processing Record14 of Set11 | nanga eboko
# Processing Record15 of Set11 | tarpon springs
# Processing Record16 of Set11 | miandrivazo
# Processing Record17 of Set11 | pingliang
# Processing Record18 of Set11 | marcona
# City not found.Skipping....
# Processing Record19 of Set11 | swift current
# Processing Record20 of Set11 | vychegodskiy
# Processing Record21 of Set11 | oranjestad
# Processing Record22 of Set11 | osa
# Processing Record23 of Set11 | tabiauea
# City not found.Skipping....
# Processing Record24 of Set11 | khandbari
# Processing Record25 of Set11 | casalecchio di reno
# Processing Record26 of Set11 | mecca
# Processing Record27 of Set11 | caronport
# Processing Record28 of Set11 | port macquarie
# Processing Record29 of Set11 | salalah
# Processing Record30 of Set11 | yokadouma
# Processing Record31 of Set11 | grindavik
# Processing Record32 of Set11 | strandby
# Processing Record33 of Set11 | hovd
# Processing Record34 of Set11 | galle
# Processing Record35 of Set11 | seguela
# Processing Record36 of Set11 | chihuahua
# Processing Record37 of Set11 | praia da vitoria
# Processing Record38 of Set11 | waingapu
# Processing Record39 of Set11 | necochea
# Processing Record40 of Set11 | ingham
# Processing Record41 of Set11 | san patricio
# Processing Record42 of Set11 | kozhva
# Processing Record43 of Set11 | nanortalik
# Processing Record44 of Set11 | sambava
# Processing Record45 of Set11 | grimshaw
# Processing Record46 of Set11 | yuzhno-yeniseyskiy
# City not found.Skipping....
# Processing Record47 of Set11 | ambovombe
# Processing Record48 of Set11 | chiesanuova
# Processing Record49 of Set11 | itarantim
# Processing Record50 of Set11 | yarmouth
# Processing Record1 of Set12 | freeport
# Processing Record2 of Set12 | muromtsevo
# Processing Record3 of Set12 | san juan
# Processing Record4 of Set12 | walvis bay
# Processing Record5 of Set12 | concordia
# Processing Record6 of Set12 | safaga
# Processing Record7 of Set12 | marrakesh
# Processing Record8 of Set12 | bhilwara
# Processing Record9 of Set12 | monrovia
# Processing Record10 of Set12 | nizhniy kuranakh
# Processing Record11 of Set12 | nyurba
# Processing Record12 of Set12 | kazalinsk
# City not found.Skipping....
# Processing Record13 of Set12 | puerto escondido
# Processing Record14 of Set12 | lansdale
# Processing Record15 of Set12 | rancho veloz
# Processing Record16 of Set12 | male
# Processing Record17 of Set12 | cedar city
# Processing Record18 of Set12 | attawapiskat
# City not found.Skipping....
# Processing Record19 of Set12 | sinnamary
# Processing Record20 of Set12 | tocache
# Processing Record21 of Set12 | oktyabrskoye
# Processing Record22 of Set12 | tambul
# City not found.Skipping....
# Processing Record23 of Set12 | dolinsk
# Processing Record24 of Set12 | vaasa
# Processing Record25 of Set12 | sorong
# Processing Record26 of Set12 | noumea
# Processing Record27 of Set12 | chapleau
# Processing Record28 of Set12 | ouesso
# Processing Record29 of Set12 | khilok
# Processing Record30 of Set12 | aripuana
# Processing Record31 of Set12 | japura
# Processing Record32 of Set12 | xuanhua
# Processing Record33 of Set12 | vallenar
# Processing Record34 of Set12 | tautira
# Processing Record35 of Set12 | mogadishu
# Processing Record36 of Set12 | chagda
# City not found.Skipping....
# Processing Record37 of Set12 | saint-augustin
# Processing Record38 of Set12 | lata
# Processing Record39 of Set12 | edd
# Processing Record40 of Set12 | banfora
# Processing Record41 of Set12 | juneau
# Processing Record42 of Set12 | najran
# Processing Record43 of Set12 | taksimo
# Processing Record44 of Set12 | lyubytino
# Processing Record45 of Set12 | capitan bado
# Processing Record46 of Set12 | masindi
# Processing Record47 of Set12 | mandera
# Processing Record48 of Set12 | batemans bay
# Processing Record49 of Set12 | semnan
# Processing Record50 of Set12 | bathsheba
# Processing Record1 of Set13 | naze
# Processing Record2 of Set13 | albox
# Processing Record3 of Set13 | moyale
# Processing Record4 of Set13 | sri aman
# Processing Record5 of Set13 | lasa
# Processing Record6 of Set13 | hit
# Processing Record7 of Set13 | namikupa
# Processing Record8 of Set13 | yulara
# Processing Record9 of Set13 | zhangye
# Processing Record10 of Set13 | ust-kan
# Processing Record11 of Set13 | khobi
# Processing Record12 of Set13 | noyabrsk
# Processing Record13 of Set13 | avera
# Processing Record14 of Set13 | ust-maya
# Processing Record15 of Set13 | zhanaozen
# Processing Record16 of Set13 | pangody
# Processing Record17 of Set13 | villablino
# Processing Record18 of Set13 | cururupu
# Processing Record19 of Set13 | madimba
# Processing Record20 of Set13 | alyangula
# Processing Record21 of Set13 | kaeo
# Processing Record22 of Set13 | kijini
# Processing Record23 of Set13 | matara
# Processing Record24 of Set13 | kargasok
# Processing Record25 of Set13 | nemuro
# Processing Record26 of Set13 | polis
# Processing Record27 of Set13 | churapcha
# Processing Record28 of Set13 | kimbe
# Processing Record29 of Set13 | liverpool
# Processing Record30 of Set13 | arenal
# Processing Record31 of Set13 | keflavik
# Processing Record32 of Set13 | tufanganj
# Processing Record33 of Set13 | zharkent
# Processing Record34 of Set13 | saint-georges
# Processing Record35 of Set13 | karanja
# Processing Record36 of Set13 | dujuma
# City not found.Skipping....
# Processing Record37 of Set13 | nizwa
# Processing Record38 of Set13 | svetlaya
# Processing Record39 of Set13 | potosi
# Processing Record40 of Set13 | todos santos
# Processing Record41 of Set13 | cumaribo
# City not found.Skipping....
# Processing Record42 of Set13 | silleda
# Processing Record43 of Set13 | nizhneyansk
# City not found.Skipping....
# Processing Record44 of Set13 | lolua
# City not found.Skipping....
# Processing Record45 of Set13 | nantucket
# Processing Record46 of Set13 | mafinga
# Processing Record47 of Set13 | iwanai
# Processing Record48 of Set13 | opuwo
# Processing Record49 of Set13 | kuche
# City not found.Skipping....
# Processing Record50 of Set13 | jibuti
# Processing Record1 of Set14 | cobija
# Processing Record2 of Set14 | sisimiut
# Processing Record3 of Set14 | caravelas
# Processing Record4 of Set14 | atar
# Processing Record5 of Set14 | porto novo
# Processing Record6 of Set14 | tikhvin
# Processing Record7 of Set14 | kanigoro
# Processing Record8 of Set14 | biharamulo
# Processing Record9 of Set14 | ranong
# Processing Record10 of Set14 | jiddah
# City not found.Skipping....
# Processing Record11 of Set14 | inhambane
# Processing Record12 of Set14 | vila velha
# Processing Record13 of Set14 | sarany
# Processing Record14 of Set14 | babanusah
# City not found.Skipping....
# Processing Record15 of Set14 | souillac
# Processing Record16 of Set14 | nova cruz
# Processing Record17 of Set14 | moose factory
# Processing Record18 of Set14 | bargal
# City not found.Skipping....
# Processing Record19 of Set14 | sitka
# Processing Record20 of Set14 | show low
# Processing Record21 of Set14 | kermanshah
# Processing Record22 of Set14 | oranjemund
# Processing Record23 of Set14 | mount isa
# Processing Record24 of Set14 | raudeberg
# Processing Record25 of Set14 | pozo colorado
# Processing Record26 of Set14 | hay river
# Processing Record27 of Set14 | san pedro de ycuamandiyu
# Processing Record28 of Set14 | novoye leushino
# Processing Record29 of Set14 | dunedin
# Processing Record30 of Set14 | koumac
# Processing Record31 of Set14 | north bend
# Processing Record32 of Set14 | takoradi
# Processing Record33 of Set14 | bilma
# Processing Record34 of Set14 | maneadero
# Processing Record35 of Set14 | altay
# Processing Record36 of Set14 | san andres
# Processing Record37 of Set14 | pecos
# Processing Record38 of Set14 | ojinaga
# Processing Record39 of Set14 | peruibe
# Processing Record40 of Set14 | rantauprapat
# Processing Record41 of Set14 | the pas
# Processing Record42 of Set14 | mehriz
# Processing Record43 of Set14 | praia
# Processing Record44 of Set14 | keskin
# Processing Record45 of Set14 | coahuayana
# Processing Record46 of Set14 | haapsalu
# Processing Record47 of Set14 | puerto lempira
# Processing Record48 of Set14 | angoche
# Processing Record49 of Set14 | chekhov
# Processing Record50 of Set14 | santa cruz de tenerife
# Processing Record1 of Set15 | bolshegrivskoye
# City not found.Skipping....
# Processing Record2 of Set15 | parrita
# Processing Record3 of Set15 | pringsewu
# Processing Record4 of Set15 | taltal
# Processing Record5 of Set15 | bermeo
# Processing Record6 of Set15 | skalistyy
# City not found.Skipping....
# Processing Record7 of Set15 | kudahuvadhoo
# Processing Record8 of Set15 | abohar
# Processing Record9 of Set15 | salou
# Processing Record10 of Set15 | buta
# Processing Record11 of Set15 | qaqortoq
# Processing Record12 of Set15 | pachino
# Processing Record13 of Set15 | brigantine
# Processing Record14 of Set15 | khandyga
# Processing Record15 of Set15 | tawkar
# City not found.Skipping....
# Processing Record16 of Set15 | gastello
# Processing Record17 of Set15 | eyl
# Processing Record18 of Set15 | kruisfontein
# Processing Record19 of Set15 | ouegoa
# Processing Record20 of Set15 | ewa beach
# Processing Record21 of Set15 | guayaramerin
# Processing Record22 of Set15 | ramkola
# Processing Record23 of Set15 | vestmanna
# Processing Record24 of Set15 | merauke
# Processing Record25 of Set15 | savannah bight
# Processing Record26 of Set15 | fort nelson
# Processing Record27 of Set15 | bangassou
# Processing Record28 of Set15 | karasburg
# Processing Record29 of Set15 | ylivieska
# Processing Record30 of Set15 | ivanivka
# Processing Record31 of Set15 | nokaneng
# Processing Record32 of Set15 | acajutla
# Processing Record33 of Set15 | kemi
# Processing Record34 of Set15 | inta
# Processing Record35 of Set15 | vanino
# Processing Record36 of Set15 | usinsk
# Processing Record37 of Set15 | solovetskiy
# City not found.Skipping....
# Processing Record38 of Set15 | kijang
# Processing Record39 of Set15 | rawlins
# Processing Record40 of Set15 | sayyan
# Processing Record41 of Set15 | ken caryl
# Processing Record42 of Set15 | west bay
# Processing Record43 of Set15 | dinguiraye
# Processing Record44 of Set15 | leshukonskoye
# Processing Record45 of Set15 | bud
# Processing Record46 of Set15 | ardistan
# City not found.Skipping....
# Processing Record47 of Set15 | namatanai
# Processing Record48 of Set15 | gurskoye
# City not found.Skipping....
# Processing Record49 of Set15 | sonoita
# Processing Record50 of Set15 | broken hill
# Processing Record1 of Set16 | kilis
# Processing Record2 of Set16 | fershampenuaz
# Processing Record3 of Set16 | poum
# Processing Record4 of Set16 | maragogi
# Processing Record5 of Set16 | kotelnich
# Processing Record6 of Set16 | tsumeb
# Processing Record7 of Set16 | lichuan
# Processing Record8 of Set16 | matagami
# Processing Record9 of Set16 | sorland
# Processing Record10 of Set16 | kathmandu
# Processing Record11 of Set16 | teshie
# Processing Record12 of Set16 | ornskoldsvik
# Processing Record13 of Set16 | sechura
# Processing Record14 of Set16 | muzquiz
# City not found.Skipping....
# Processing Record15 of Set16 | tasbuget
# City not found.Skipping....
# Processing Record16 of Set16 | choa saidan shah
# Processing Record17 of Set16 | uniontown
# Processing Record18 of Set16 | sharjah
# Processing Record19 of Set16 | pochutla
# Processing Record20 of Set16 | alice springs
# Processing Record21 of Set16 | mentougou
# Processing Record22 of Set16 | kiama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 713

# %%
#Adding the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0                     Albany  42.6001  -73.9662     59.34        34
# 1                  Yuancheng  36.6520  107.7896     57.58        71
# 2                 High Level  58.5169 -117.1360     37.51        93
# 3                    Rikitea -23.1203 -134.9692     77.29        83
# 4                    Mataura -46.1927  168.8643     57.47        99
# 5                  Jamestown  42.0970  -79.2353     65.52        41
# 6  Petropavlovsk-Kamchatskiy  53.0452  158.6483     48.79        66
# 7               Punta Arenas -53.1500  -70.9167     50.11        66
# 8                      Kapit   2.0167  112.9333     74.32        99
# 9                 Georgetown   5.4112  100.3354     84.13        93
#
#    Cloudiness  Wind Speed Country Current Description
# 0         100        1.01      US     overcast clouds
# 1         100        4.32      CN     overcast clouds
# 2         100       13.80      CA          light rain
# 3          63       13.22      PF          light rain
# 4         100        2.62      NZ          light rain
# 5           0        8.05      US           clear sky
# 6           0        6.71      RU           clear sky
# 7          20       31.07      CL          few clouds
# 8         100        0.29      MY     overcast clouds
# 9          20        8.05      MY          few clouds

# %%
new_col_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_col_order]
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                     Albany      US  42.6001  -73.9662     59.34        34
# 1                  Yuancheng      CN  36.6520  107.7896     57.58        71
# 2                 High Level      CA  58.5169 -117.1360     37.51        93
# 3                    Rikitea      PF -23.1203 -134.9692     77.29        83
# 4                    Mataura      NZ -46.1927  168.8643     57.47        99
# 5                  Jamestown      US  42.0970  -79.2353     65.52        41
# 6  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     48.79        66
# 7               Punta Arenas      CL -53.1500  -70.9167     50.11        66
# 8                      Kapit      MY   2.0167  112.9333     74.32        99
# 9                 Georgetown      MY   5.4112  100.3354     84.13        93
#
#    Cloudiness  Wind Speed Current Description
# 0         100        1.01     overcast clouds
# 1         100        4.32     overcast clouds
# 2         100       13.80          light rain
# 3          63       13.22          light rain
# 4         100        2.62          light rain
# 5           0        8.05           clear sky
# 6           0        6.71           clear sky
# 7          20       31.07          few clouds
# 8         100        0.29     overcast clouds
# 9          20        8.05          few clouds

# %%
#Export the DataFrame as a CSV file
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file,index_label = "City_ID")
